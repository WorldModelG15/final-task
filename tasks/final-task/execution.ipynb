# %%
import gym_duckietown as gd
# Out:
# DEBUG:commons:version: 6.2.4 *
# DEBUG:typing:version: 6.2.3
# DEBUG:duckietown_world:duckietown-world version 6.2.38 path /root/.pyenv/versions/3.8.0/lib/python3.8/site-packages
# DEBUG:geometry:PyGeometry-z6 version 2.1.4 path /root/.pyenv/versions/3.8.0/lib/python3.8/site-packages
# DEBUG:aido_schemas:aido-protocols version 6.0.59 path /root/.pyenv/versions/3.8.0/lib/python3.8/site-packages
# DEBUG:nodes:version 6.2.13 path /root/.pyenv/versions/3.8.0/lib/python3.8/site-packages pyparsing 3.0.6
# DEBUG:gym-duckietown:gym-duckietown version 6.1.31 path /root/mnt/final-task/env/src
# {'audio': ('xaudio2', 'directsound', 'openal', 'pulse', 'silent'), 'debug_font': False, 'debug_gl': True, 'debug_gl_trace': False, 'debug_gl_trace_args': False, 'debug_graphics_batch': False, 'debug_lib': False, 'debug_media': False, 'debug_texture': False, 'debug_trace': False, 'debug_trace_args': False, 'debug_trace_depth': 1, 'debug_trace_flush': True, 'debug_win32': False, 'debug_x11': False, 'graphics_vbo': True, 'shadow_window': True, 'vsync': None, 'xsync': True, 'xlib_fullscreen_override_redirect': False, 'darwin_cocoa': True, 'search_local_libs': True, 'advanced_font_features': False, 'headless': False, 'headless_device': 0, 'win32_disable_shaping': False}

# %%
from utils.env import launch_env
from utils.wrappers import NormalizeWrapper, ImgWrapper, DtRewardWrapper, ActionWrapper, ResizeWrapper
import matplotlib.pyplot as plt

# %% [markdown]
# マップ一覧
# - 4way.yaml
# - 4way_bordered.yaml
# - Caltech_loop01.yaml
# - ETHZ_autolab_fast_track.yaml
# - ETHZ_autolab_technical_track.yaml
# - ETHZ_autolab_technical_track_bordered.yaml
# - ETHZ_loop.yaml
# - ETHZ_loop_bordered.yaml
# - ETH_intersection_map.yaml
# - ETH_large_intersect.yaml
# - ETH_large_loop.yaml
# - ETH_small_intersect.yaml
# - ETH_small_loop.yaml
# - ETH_small_loop_1.yaml
# - ETH_small_loop_2.yaml
# - ETH_small_loop_2_bordered.yaml
# - ETH_small_loop_3.yaml
# - ETU_autolab_track.yaml
# - MOOC_modcon.yaml
# - Montreal_loop.yaml
# - TTIC_large_loop.yaml
# - TTIC_loop.yaml
# - TTIC_ripltown.yaml
# - calibration_map_ext.yaml
# - calibration_map_int.yaml
# - experiment_loop.yaml
# - field1.yaml
# - loop_dyn_duckiebots.yaml
# - loop_empty.yaml
# - loop_obstacles.yaml
# - loop_pedestrians.yaml
# - regress_4way_adam.yaml
# - regress_4way_drivable.yaml
# - robotarium1.yaml
# - robotarium2.yaml
# - small_loop.yaml
# - small_loop_bordered.yaml
# - small_loop_cw.yaml
# - straight_road.yaml
# - straight_road_down.yaml
# - udem1.yaml
# - udem1_empty.yaml
# - zigzag_dists.yaml
# - zigzag_dists_bordered.yaml

# %%
env = launch_env(map_name="loop_pedestrians")
print("Initialized environment")

# Wrappers
env = ResizeWrapper(env)
env = NormalizeWrapper(env)
env = ImgWrapper(env)  # to make the images from 160x120x3 into 3x160x120
env = ActionWrapper(env)
env = DtRewardWrapper(env)
print("Initialized Wrappers")
# 処理後の観測
state_dim = env.observation_space.shape
print(f"state_dim: {state_dim}")
# 行動次元（２つの車輪のトルク[-1,1]）
action_dim = env.action_space.shape[0]
print(f"action_dim: {action_dim}")
# 最大トルク
max_action = float(env.action_space.high[0])
print(f"max_action: {max_action}")
# Out:
# INFO:gym-duckietown:Information about the graphics card:
#  pyglet_version: 1.5.23
#     information: dict[4]
#                  │ vendor: Mesa/X.org
#                  │ renderer: llvmpipe (LLVM 12.0.0, 256 bits)
#                  │ version: 3.1 Mesa 21.2.6
#                  │ shading-language-version: 1.40
#   nvidia_around: True
# INFO:duckietown_world: data: /root/.pyenv/versions/3.8.0/lib/python3.8/site-packages/duckietown_world/data
# DEBUG:gym-duckietown:loading map file "/root/.pyenv/versions/3.8.0/lib/python3.8/site-packages/duckietown_world/data/gd1/maps/loop_pedestrians.yaml"
# INFO:gym-duckietown:done
# DEBUG:gym-duckietown:loading mesh 'duckiebot' from file_path '/root/.pyenv/versions/3.8.0/lib/python3.8/site-packages/duckietown_world/data/gd1/meshes/duckiebot/duckiebot.obj'
# DEBUG:gym-duckietown:loading materials from /root/.pyenv/versions/3.8.0/lib/python3.8/site-packages/duckietown_world/data/gd1/meshes/duckiebot/duckiebot.mtl
# DEBUG:gym-duckietown:loading texture: /root/.pyenv/versions/3.8.0/lib/python3.8/site-packages/duckietown_world/data/gd1/meshes/duckiebot/circlegrid-square.jpg
# DEBUG:gym-duckietown:loading texture: /root/.pyenv/versions/3.8.0/lib/python3.8/site-packages/duckietown_world/data/gd1/meshes/duckie/duckie.png
# DEBUG:gym-duckietown:loading mesh 'duckie' from file_path '/root/.pyenv/versions/3.8.0/lib/python3.8/site-packages/duckietown_world/data/gd1/meshes/duckie/duckie.obj'
# DEBUG:gym-duckietown:loading mesh 'cone' from file_path '/root/.pyenv/versions/3.8.0/lib/python3.8/site-packages/duckietown_world/data/gd1/meshes/cone/cone.obj'
# DEBUG:gym-duckietown:loading texture: /root/.pyenv/versions/3.8.0/lib/python3.8/site-packages/duckietown_world/data/gd1/meshes/cone/cone.png
# DEBUG:gym-duckietown:loading mesh 'barrier' from file_path '/root/.pyenv/versions/3.8.0/lib/python3.8/site-packages/duckietown_world/data/gd1/meshes/barrier/barrier.obj'
# DEBUG:gym-duckietown:loading texture: /root/.pyenv/versions/3.8.0/lib/python3.8/site-packages/duckietown_world/data/gd1/meshes/barrier/barrier.png
# DEBUG:gym-duckietown:loading texture: /root/.pyenv/versions/3.8.0/lib/python3.8/site-packages/duckietown_world/data/gd1/textures/tiles-processed/photos/floor/texture.jpg
# DEBUG:gym-duckietown:loading texture: /root/.pyenv/versions/3.8.0/lib/python3.8/site-packages/duckietown_world/data/gd1/textures/tiles-processed/photos/curve_left/texture.jpg
# DEBUG:gym-duckietown:loading texture: /root/.pyenv/versions/3.8.0/lib/python3.8/site-packages/duckietown_world/data/gd1/textures/tiles-processed/photos/straight/texture.jpg
# DEBUG:gym-duckietown:loading texture: /root/.pyenv/versions/3.8.0/lib/python3.8/site-packages/duckietown_world/data/gd1/textures/tiles-processed/photos/curve_right/texture.jpg
# DEBUG:gym-duckietown:[4.14228125 0.         2.65556531] corresponds to tile at (7, 4) which is not drivable: {'coords': (7, 4), 'kind': 'floor', 'angle': 1, 'drivable': False, 'texture': <gym_duckietown.graphics.Texture object at 0x7f237f63daf0>, 'color': array([1, 1, 1, 1])}
# DEBUG:gym-duckietown:Invalid pose. Collision free: True On drivable area: False
# DEBUG:gym-duckietown:safety_factor: 1.3
# DEBUG:gym-duckietown:pos: [4.04650084 0.         2.67379611]
# DEBUG:gym-duckietown:l_pos: [3.95072043 0.         2.69202692]
# DEBUG:gym-duckietown:r_pos: [4.14228125 0.         2.65556531]
# DEBUG:gym-duckietown:f_pos: [4.02462387 0.         2.55885962]
# DEBUG:gym-duckietown:[4.04767254 0.         2.93598487] corresponds to tile at (6, 5) which is not drivable: {'coords': (6, 5), 'kind': 'floor', 'angle': 1, 'drivable': False, 'texture': <gym_duckietown.graphics.Texture object at 0x7f237f63dd30>, 'color': array([1, 1, 1, 1])}
# DEBUG:gym-duckietown:Invalid pose. Collision free: True On drivable area: False
# DEBUG:gym-duckietown:safety_factor: 1.3
# DEBUG:gym-duckietown:pos: [3.99099581 0.         2.85665015]
# DEBUG:gym-duckietown:l_pos: [4.04767254 0.         2.93598487]
# DEBUG:gym-duckietown:r_pos: [3.93431907 0.         2.77731543]
# DEBUG:gym-duckietown:f_pos: [3.89579414 0.         2.92466223]
# DEBUG:gym-duckietown:[4.1289492 0.        2.3900463] corresponds to tile at (7, 4) which is not drivable: {'coords': (7, 4), 'kind': 'floor', 'angle': 1, 'drivable': False, 'texture': <gym_duckietown.graphics.Texture object at 0x7f237f63daf0>, 'color': array([1, 1, 1, 1])}
# DEBUG:gym-duckietown:Invalid pose. Collision free: True On drivable area: False
# DEBUG:gym-duckietown:safety_factor: 1.3
# DEBUG:gym-duckietown:pos: [4.01769695 0.         2.42626695]
# DEBUG:gym-duckietown:l_pos: [3.98751307 0.         2.33355674]
# DEBUG:gym-duckietown:r_pos: [4.04788082 0.         2.51897716]
# DEBUG:gym-duckietown:f_pos: [4.1289492 0.        2.3900463]
# DEBUG:gym-duckietown:[4.09882827 0.         2.43294309] corresponds to tile at (7, 4) which is not drivable: {'coords': (7, 4), 'kind': 'floor', 'angle': 1, 'drivable': False, 'texture': <gym_duckietown.graphics.Texture object at 0x7f237f63daf0>, 'color': array([1, 1, 1, 1])}
# DEBUG:gym-duckietown:Invalid pose. Collision free: True On drivable area: False
# DEBUG:gym-duckietown:safety_factor: 1.3
# DEBUG:gym-duckietown:pos: [4.01129793 0.         2.3553065 ]
# DEBUG:gym-duckietown:l_pos: [4.0759951  0.         2.28236456]
# DEBUG:gym-duckietown:r_pos: [3.94660077 0.         2.42824844]
# DEBUG:gym-duckietown:f_pos: [4.09882827 0.         2.43294309]
# DEBUG:gym-duckietown:[3.87357958 0.         2.94821608] corresponds to tile at (6, 5) which is not drivable: {'coords': (6, 5), 'kind': 'floor', 'angle': 1, 'drivable': False, 'texture': <gym_duckietown.graphics.Texture object at 0x7f237f63dd30>, 'color': array([1, 1, 1, 1])}
# DEBUG:gym-duckietown:Invalid pose. Collision free: True On drivable area: False
# DEBUG:gym-duckietown:safety_factor: 1.3
# DEBUG:gym-duckietown:pos: [3.87357958 0.         2.94821608]
# DEBUG:gym-duckietown:l_pos: [3.77707045 0.         2.93435109]
# DEBUG:gym-duckietown:r_pos: [3.9700887  0.         2.96208107]
# DEBUG:gym-duckietown:f_pos: [3.89021756 0.         2.83240513]
# DEBUG:gym-duckietown:[3.85635244 0.         2.99082616] corresponds to tile at (6, 5) which is not drivable: {'coords': (6, 5), 'kind': 'floor', 'angle': 1, 'drivable': False, 'texture': <gym_duckietown.graphics.Texture object at 0x7f237f63dd30>, 'color': array([1, 1, 1, 1])}
# DEBUG:gym-duckietown:Invalid pose. Collision free: True On drivable area: False
# DEBUG:gym-duckietown:safety_factor: 1.3
# DEBUG:gym-duckietown:pos: [3.85730904 0.         2.87383007]
# DEBUG:gym-duckietown:l_pos: [3.95480578 0.         2.87462723]
# DEBUG:gym-duckietown:r_pos: [3.7598123  0.         2.87303291]
# DEBUG:gym-duckietown:f_pos: [3.85635244 0.         2.99082616]
# DEBUG:gym-duckietown:[3.73839767 0.         2.98822487] corresponds to tile at (6, 5) which is not drivable: {'coords': (6, 5), 'kind': 'floor', 'angle': 1, 'drivable': False, 'texture': <gym_duckietown.graphics.Texture object at 0x7f237f63dd30>, 'color': array([1, 1, 1, 1])}
# DEBUG:gym-duckietown:Invalid pose. Collision free: True On drivable area: False
# DEBUG:gym-duckietown:safety_factor: 1.3
# DEBUG:gym-duckietown:pos: [3.68488691 0.         2.9067212 ]
# DEBUG:gym-duckietown:l_pos: [3.63137614 0.         2.82521753]
# DEBUG:gym-duckietown:r_pos: [3.73839767 0.         2.98822487]
# DEBUG:gym-duckietown:f_pos: [3.78269131 0.         2.84250828]
# DEBUG:gym-duckietown:[4.09675828 0.         2.60001624] corresponds to tile at (7, 4) which is not drivable: {'coords': (7, 4), 'kind': 'floor', 'angle': 1, 'drivable': False, 'texture': <gym_duckietown.graphics.Texture object at 0x7f237f63daf0>, 'color': array([1, 1, 1, 1])}
# DEBUG:gym-duckietown:Invalid pose. Collision free: True On drivable area: False
# DEBUG:gym-duckietown:safety_factor: 1.3
# DEBUG:gym-duckietown:pos: [4.09675828 0.         2.60001624]
# DEBUG:gym-duckietown:l_pos: [4.19393893 0.         2.60790112]
# DEBUG:gym-duckietown:r_pos: [3.99957763 0.         2.59213136]
# DEBUG:gym-duckietown:f_pos: [4.08729642 0.         2.71663302]
# DEBUG:gym-duckietown:[4.10913249 0.         2.6493956 ] corresponds to tile at (7, 4) which is not drivable: {'coords': (7, 4), 'kind': 'floor', 'angle': 1, 'drivable': False, 'texture': <gym_duckietown.graphics.Texture object at 0x7f237f63daf0>, 'color': array([1, 1, 1, 1])}
# DEBUG:gym-duckietown:Invalid pose. Collision free: True On drivable area: False
# DEBUG:gym-duckietown:safety_factor: 1.3
# DEBUG:gym-duckietown:pos: [3.99782649 0.         2.61334043]
# DEBUG:gym-duckietown:l_pos: [4.02787247 0.         2.52058544]
# DEBUG:gym-duckietown:r_pos: [3.96778052 0.         2.70609543]
# DEBUG:gym-duckietown:f_pos: [4.10913249 0.         2.6493956 ]
# DEBUG:gym-duckietown:[4.11805589 0.         2.79716451] corresponds to tile at (7, 4) which is not drivable: {'coords': (7, 4), 'kind': 'floor', 'angle': 1, 'drivable': False, 'texture': <gym_duckietown.graphics.Texture object at 0x7f237f63daf0>, 'color': array([1, 1, 1, 1])}
# DEBUG:gym-duckietown:Invalid pose. Collision free: True On drivable area: False
# DEBUG:gym-duckietown:safety_factor: 1.3
# DEBUG:gym-duckietown:pos: [4.05371356 0.         2.72390938]
# DEBUG:gym-duckietown:l_pos: [4.11805589 0.         2.79716451]
# DEBUG:gym-duckietown:r_pos: [3.98937122 0.         2.65065425]
# DEBUG:gym-duckietown:f_pos: [3.9658074  0.         2.80112018]
# DEBUG:gym-duckietown:[3.76572218 0.         2.946157  ] corresponds to tile at (6, 5) which is not drivable: {'coords': (6, 5), 'kind': 'floor', 'angle': 1, 'drivable': False, 'texture': <gym_duckietown.graphics.Texture object at 0x7f237f63dd30>, 'color': array([1, 1, 1, 1])}
# DEBUG:gym-duckietown:Invalid pose. Collision free: True On drivable area: False
# DEBUG:gym-duckietown:safety_factor: 1.3
# DEBUG:gym-duckietown:pos: [3.76572218 0.         2.946157  ]
# DEBUG:gym-duckietown:l_pos: [3.6754953  0.         2.98310778]
# DEBUG:gym-duckietown:r_pos: [3.85594906 0.         2.90920622]
# DEBUG:gym-duckietown:f_pos: [3.72138125 0.         2.83788474]
# DEBUG:gym-duckietown:[4.1389418  0.         2.95121192] corresponds to tile at (7, 5) which is not drivable: {'coords': (7, 5), 'kind': 'floor', 'angle': 1, 'drivable': False, 'texture': <gym_duckietown.graphics.Texture object at 0x7f237f63dd90>, 'color': array([1, 1, 1, 1])}
# DEBUG:gym-duckietown:Invalid pose. Collision free: True On drivable area: False
# DEBUG:gym-duckietown:safety_factor: 1.3
# DEBUG:gym-duckietown:pos: [4.06540953 0.         2.88718649]
# DEBUG:gym-duckietown:l_pos: [3.99187725 0.         2.82316107]
# DEBUG:gym-duckietown:r_pos: [4.1389418  0.         2.95121192]
# DEBUG:gym-duckietown:f_pos: [4.14224004 0.         2.79894777]
# DEBUG:gym-duckietown:[3.99458453 0.         2.92603688] corresponds to tile at (6, 5) which is not drivable: {'coords': (6, 5), 'kind': 'floor', 'angle': 1, 'drivable': False, 'texture': <gym_duckietown.graphics.Texture object at 0x7f237f63dd30>, 'color': array([1, 1, 1, 1])}
# DEBUG:gym-duckietown:Invalid pose. Collision free: True On drivable area: False
# DEBUG:gym-duckietown:safety_factor: 1.3
# DEBUG:gym-duckietown:pos: [3.89942239 0.         2.90481387]
# DEBUG:gym-duckietown:l_pos: [3.80426025 0.         2.88359085]
# DEBUG:gym-duckietown:r_pos: [3.99458453 0.         2.92603688]
# DEBUG:gym-duckietown:f_pos: [3.92489001 0.         2.79061929]
# DEBUG:gym-duckietown:[4.14241432 0.         2.47275846] corresponds to tile at (7, 4) which is not drivable: {'coords': (7, 4), 'kind': 'floor', 'angle': 1, 'drivable': False, 'texture': <gym_duckietown.graphics.Texture object at 0x7f237f63daf0>, 'color': array([1, 1, 1, 1])}
# DEBUG:gym-duckietown:Invalid pose. Collision free: True On drivable area: False
# DEBUG:gym-duckietown:safety_factor: 1.3
# DEBUG:gym-duckietown:pos: [4.04820438 0.         2.49787293]
# DEBUG:gym-duckietown:l_pos: [4.14241432 0.         2.47275846]
# DEBUG:gym-duckietown:r_pos: [3.95399444 0.         2.52298741]
# DEBUG:gym-duckietown:f_pos: [4.07834175 0.         2.61092486]
# DEBUG:gym-duckietown:[4.00842437 0.         2.93275079] corresponds to tile at (6, 5) which is not drivable: {'coords': (6, 5), 'kind': 'floor', 'angle': 1, 'drivable': False, 'texture': <gym_duckietown.graphics.Texture object at 0x7f237f63dd30>, 'color': array([1, 1, 1, 1])}
# DEBUG:gym-duckietown:Invalid pose. Collision free: True On drivable area: False
# DEBUG:gym-duckietown:safety_factor: 1.3
# DEBUG:gym-duckietown:pos: [4.00842437 0.         2.93275079]
# DEBUG:gym-duckietown:l_pos: [3.95661462 0.         3.01534619]
# DEBUG:gym-duckietown:r_pos: [4.06023412 0.         2.85015539]
# DEBUG:gym-duckietown:f_pos: [3.90930989 0.         2.87057909]
# DEBUG:gym-duckietown:[3.62260614 0.         2.9618906 ] corresponds to tile at (6, 5) which is not drivable: {'coords': (6, 5), 'kind': 'floor', 'angle': 1, 'drivable': False, 'texture': <gym_duckietown.graphics.Texture object at 0x7f237f63dd30>, 'color': array([1, 1, 1, 1])}
# DEBUG:gym-duckietown:Invalid pose. Collision free: True On drivable area: False
# DEBUG:gym-duckietown:safety_factor: 1.3
# DEBUG:gym-duckietown:pos: [3.60963095 0.         2.86525782]
# DEBUG:gym-duckietown:l_pos: [3.62260614 0.         2.9618906 ]
# DEBUG:gym-duckietown:r_pos: [3.59665576 0.         2.76862503]
# DEBUG:gym-duckietown:f_pos: [3.49367161 0.         2.88082804]
# DEBUG:gym-duckietown:[4.12458834 0.         2.30620707] corresponds to tile at (7, 3) which is not drivable: {'coords': (7, 3), 'kind': 'floor', 'angle': 1, 'drivable': False, 'texture': <gym_duckietown.graphics.Texture object at 0x7f237f63d700>, 'color': array([1, 1, 1, 1])}
# DEBUG:gym-duckietown:Invalid pose. Collision free: True On drivable area: False
# DEBUG:gym-duckietown:safety_factor: 1.3
# DEBUG:gym-duckietown:pos: [4.04849014 0.         2.36716045]
# DEBUG:gym-duckietown:l_pos: [4.12458834 0.         2.30620707]
# DEBUG:gym-duckietown:r_pos: [3.97239194 0.         2.42811383]
# DEBUG:gym-duckietown:f_pos: [4.1216342  0.         2.45847828]
# DEBUG:gym-duckietown:[3.62778488 0.         2.98723015] corresponds to tile at (6, 5) which is not drivable: {'coords': (6, 5), 'kind': 'floor', 'angle': 1, 'drivable': False, 'texture': <gym_duckietown.graphics.Texture object at 0x7f237f63dd30>, 'color': array([1, 1, 1, 1])}
# DEBUG:gym-duckietown:Invalid pose. Collision free: True On drivable area: False
# DEBUG:gym-duckietown:safety_factor: 1.3
# DEBUG:gym-duckietown:pos: [3.69347863 0.         2.91518447]
# DEBUG:gym-duckietown:l_pos: [3.62778488 0.         2.98723015]
# DEBUG:gym-duckietown:r_pos: [3.75917238 0.         2.84313878]
# DEBUG:gym-duckietown:f_pos: [3.60702381 0.         2.83635196]
# DEBUG:gym-duckietown:[3.56387164 0.         2.9661961 ] corresponds to tile at (6, 5) which is not drivable: {'coords': (6, 5), 'kind': 'floor', 'angle': 1, 'drivable': False, 'texture': <gym_duckietown.graphics.Texture object at 0x7f237f63dd30>, 'color': array([1, 1, 1, 1])}
# DEBUG:gym-duckietown:Invalid pose. Collision free: True On drivable area: False
# DEBUG:gym-duckietown:safety_factor: 1.3
# DEBUG:gym-duckietown:pos: [3.57835524 0.         2.85009604]
# DEBUG:gym-duckietown:l_pos: [3.6751053 0.        2.8621657]
# DEBUG:gym-duckietown:r_pos: [3.48160519 0.         2.83802637]
# DEBUG:gym-duckietown:f_pos: [3.56387164 0.         2.9661961 ]
# DEBUG:gym-duckietown:[3.66371097 0.         2.92913292] corresponds to tile at (6, 5) which is not drivable: {'coords': (6, 5), 'kind': 'floor', 'angle': 1, 'drivable': False, 'texture': <gym_duckietown.graphics.Texture object at 0x7f237f63dd30>, 'color': array([1, 1, 1, 1])}
# DEBUG:gym-duckietown:Invalid pose. Collision free: True On drivable area: False
# DEBUG:gym-duckietown:safety_factor: 1.3
# DEBUG:gym-duckietown:pos: [3.70881533 0.         2.84269308]
# DEBUG:gym-duckietown:l_pos: [3.66371097 0.         2.92913292]
# DEBUG:gym-duckietown:r_pos: [3.75391969 0.         2.75625323]
# DEBUG:gym-duckietown:f_pos: [3.60508751 0.         2.78856785]
# DEBUG:gym-duckietown:[4.18064223 0.         2.61731383] corresponds to tile at (7, 4) which is not drivable: {'coords': (7, 4), 'kind': 'floor', 'angle': 1, 'drivable': False, 'texture': <gym_duckietown.graphics.Texture object at 0x7f237f63daf0>, 'color': array([1, 1, 1, 1])}
# DEBUG:gym-duckietown:Invalid pose. Collision free: True On drivable area: False
# DEBUG:gym-duckietown:safety_factor: 1.3
# DEBUG:gym-duckietown:pos: [4.06696847 0.         2.64501358]
# DEBUG:gym-duckietown:l_pos: [4.04388535 0.         2.55028544]
# DEBUG:gym-duckietown:r_pos: [4.09005159 0.         2.73974171]
# DEBUG:gym-duckietown:f_pos: [4.18064223 0.         2.61731383]
# DEBUG:gym-duckietown:[4.10181199 0.         2.70197976] corresponds to tile at (7, 4) which is not drivable: {'coords': (7, 4), 'kind': 'floor', 'angle': 1, 'drivable': False, 'texture': <gym_duckietown.graphics.Texture object at 0x7f237f63daf0>, 'color': array([1, 1, 1, 1])}
# DEBUG:gym-duckietown:Invalid pose. Collision free: True On drivable area: False
# DEBUG:gym-duckietown:safety_factor: 1.3
# DEBUG:gym-duckietown:pos: [4.01348296 0.         2.66069741]
# DEBUG:gym-duckietown:l_pos: [4.10181199 0.         2.70197976]
# DEBUG:gym-duckietown:r_pos: [3.92515393 0.         2.61941506]
# DEBUG:gym-duckietown:f_pos: [3.96394414 0.         2.76669224]
# DEBUG:gym-duckietown:[4.16784912 0.         2.75179452] corresponds to tile at (7, 4) which is not drivable: {'coords': (7, 4), 'kind': 'floor', 'angle': 1, 'drivable': False, 'texture': <gym_duckietown.graphics.Texture object at 0x7f237f63daf0>, 'color': array([1, 1, 1, 1])}
# DEBUG:gym-duckietown:Invalid pose. Collision free: True On drivable area: False
# DEBUG:gym-duckietown:safety_factor: 1.3
# DEBUG:gym-duckietown:pos: [4.07770896 0.         2.78895634]
# DEBUG:gym-duckietown:l_pos: [3.98756879 0.         2.82611816]
# DEBUG:gym-duckietown:r_pos: [4.16784912 0.         2.75179452]
# DEBUG:gym-duckietown:f_pos: [4.03311477 0.         2.68078814]
# DEBUG:gym-duckietown:[3.45377934 0.         2.93295311] corresponds to tile at (5, 5) which is not drivable: {'coords': (5, 5), 'kind': 'floor', 'angle': 1, 'drivable': False, 'texture': <gym_duckietown.graphics.Texture object at 0x7f237f63dcd0>, 'color': array([1, 1, 1, 1])}
# DEBUG:gym-duckietown:Invalid pose. Collision free: True On drivable area: False
# DEBUG:gym-duckietown:safety_factor: 1.3
# DEBUG:gym-duckietown:pos: [3.492958   0.         2.84367107]
# DEBUG:gym-duckietown:l_pos: [3.53213666 0.         2.75438903]
# DEBUG:gym-duckietown:r_pos: [3.45377934 0.         2.93295311]
# DEBUG:gym-duckietown:f_pos: [3.60009644 0.         2.89068546]
# DEBUG:gym-duckietown:[3.53688906 0.         2.96309783] corresponds to tile at (6, 5) which is not drivable: {'coords': (6, 5), 'kind': 'floor', 'angle': 1, 'drivable': False, 'texture': <gym_duckietown.graphics.Texture object at 0x7f237f63dd30>, 'color': array([1, 1, 1, 1])}
# DEBUG:gym-duckietown:Invalid pose. Collision free: True On drivable area: False
# DEBUG:gym-duckietown:safety_factor: 1.3
# DEBUG:gym-duckietown:pos: [3.53801423 0.         2.86560432]
# DEBUG:gym-duckietown:l_pos: [3.53913939 0.         2.76811081]
# DEBUG:gym-duckietown:r_pos: [3.53688906 0.         2.96309783]
# DEBUG:gym-duckietown:f_pos: [3.65500644 0.         2.86695452]
# DEBUG:gym-duckietown:[4.11310044 0.         2.3019226 ] corresponds to tile at (7, 3) which is not drivable: {'coords': (7, 3), 'kind': 'floor', 'angle': 1, 'drivable': False, 'texture': <gym_duckietown.graphics.Texture object at 0x7f237f63d700>, 'color': array([1, 1, 1, 1])}
# DEBUG:gym-duckietown:Invalid pose. Collision free: True On drivable area: False
# DEBUG:gym-duckietown:safety_factor: 1.3
# DEBUG:gym-duckietown:pos: [4.05620606 0.         2.38110138]
# DEBUG:gym-duckietown:l_pos: [4.11310044 0.         2.3019226 ]
# DEBUG:gym-duckietown:r_pos: [3.99931168 0.         2.46028017]
# DEBUG:gym-duckietown:f_pos: [4.1512206  0.         2.44937464]
# DEBUG:gym-duckietown:[3.90770915 0.         2.9345512 ] corresponds to tile at (6, 5) which is not drivable: {'coords': (6, 5), 'kind': 'floor', 'angle': 1, 'drivable': False, 'texture': <gym_duckietown.graphics.Texture object at 0x7f237f63dd30>, 'color': array([1, 1, 1, 1])}
# DEBUG:gym-duckietown:Invalid pose. Collision free: True On drivable area: False
# DEBUG:gym-duckietown:safety_factor: 1.3
# DEBUG:gym-duckietown:pos: [3.98204381 0.         2.87145914]
# DEBUG:gym-duckietown:l_pos: [4.05637847 0.         2.80836708]
# DEBUG:gym-duckietown:r_pos: [3.90770915 0.         2.9345512 ]
# DEBUG:gym-duckietown:f_pos: [4.05775429 0.         2.96066073]
# DEBUG:gym-duckietown:[4.11994182 0.         2.86759793] corresponds to tile at (7, 4) which is not drivable: {'coords': (7, 4), 'kind': 'floor', 'angle': 1, 'drivable': False, 'texture': <gym_duckietown.graphics.Texture object at 0x7f237f63daf0>, 'color': array([1, 1, 1, 1])}
# DEBUG:gym-duckietown:Invalid pose. Collision free: True On drivable area: False
# DEBUG:gym-duckietown:safety_factor: 1.3
# DEBUG:gym-duckietown:pos: [4.0193131  0.         2.80790822]
# DEBUG:gym-duckietown:l_pos: [4.06905453 0.         2.72405096]
# DEBUG:gym-duckietown:r_pos: [3.96957168 0.         2.89176548]
# DEBUG:gym-duckietown:f_pos: [4.11994182 0.         2.86759793]
# DEBUG:gym-duckietown:[4.16441252 0.         2.80995003] corresponds to tile at (7, 4) which is not drivable: {'coords': (7, 4), 'kind': 'floor', 'angle': 1, 'drivable': False, 'texture': <gym_duckietown.graphics.Texture object at 0x7f237f63daf0>, 'color': array([1, 1, 1, 1])}
# DEBUG:gym-duckietown:Invalid pose. Collision free: True On drivable area: False
# DEBUG:gym-duckietown:safety_factor: 1.3
# DEBUG:gym-duckietown:pos: [4.07692876 0.         2.76690539]
# DEBUG:gym-duckietown:l_pos: [4.16441252 0.         2.80995003]
# DEBUG:gym-duckietown:r_pos: [3.989445   0.         2.72386074]
# DEBUG:gym-duckietown:f_pos: [4.02527519 0.         2.8718859 ]
# DEBUG:gym-duckietown:[4.1374746  0.         2.77941404] corresponds to tile at (7, 4) which is not drivable: {'coords': (7, 4), 'kind': 'floor', 'angle': 1, 'drivable': False, 'texture': <gym_duckietown.graphics.Texture object at 0x7f237f63daf0>, 'color': array([1, 1, 1, 1])}
# DEBUG:gym-duckietown:Invalid pose. Collision free: True On drivable area: False
# DEBUG:gym-duckietown:safety_factor: 1.3
# DEBUG:gym-duckietown:pos: [4.02488679 0.         2.74758663]
# DEBUG:gym-duckietown:l_pos: [4.05140963 0.         2.65376345]
# DEBUG:gym-duckietown:r_pos: [3.99836395 0.         2.84140981]
# DEBUG:gym-duckietown:f_pos: [4.1374746  0.         2.77941404]
# DEBUG:gym-duckietown:[3.96391382 0.         2.98927646] corresponds to tile at (6, 5) which is not drivable: {'coords': (6, 5), 'kind': 'floor', 'angle': 1, 'drivable': False, 'texture': <gym_duckietown.graphics.Texture object at 0x7f237f63dd30>, 'color': array([1, 1, 1, 1])}
# DEBUG:gym-duckietown:Invalid pose. Collision free: True On drivable area: False
# DEBUG:gym-duckietown:safety_factor: 1.3
# DEBUG:gym-duckietown:pos: [3.94008769 0.         2.89473247]
# DEBUG:gym-duckietown:l_pos: [3.96391382 0.         2.98927646]
# DEBUG:gym-duckietown:r_pos: [3.91626155 0.         2.80018849]
# DEBUG:gym-duckietown:f_pos: [3.8266349  0.         2.92332384]
# DEBUG:gym-duckietown:[3.46890598 0.         2.32471769] corresponds to tile at (5, 3) which is not drivable: {'coords': (5, 3), 'kind': 'floor', 'angle': 1, 'drivable': False, 'texture': <gym_duckietown.graphics.Texture object at 0x7f237f63d640>, 'color': array([1, 1, 1, 1])}
# DEBUG:gym-duckietown:Invalid pose. Collision free: True On drivable area: False
# DEBUG:gym-duckietown:safety_factor: 1.3
# DEBUG:gym-duckietown:pos: [3.53669545 0.         2.42007799]
# DEBUG:gym-duckietown:l_pos: [3.45722854 0.         2.47656922]
# DEBUG:gym-duckietown:r_pos: [3.61616237 0.         2.36358676]
# DEBUG:gym-duckietown:f_pos: [3.46890598 0.         2.32471769]
# DEBUG:gym-duckietown:[3.64056496 0.         2.97341289] corresponds to tile at (6, 5) which is not drivable: {'coords': (6, 5), 'kind': 'floor', 'angle': 1, 'drivable': False, 'texture': <gym_duckietown.graphics.Texture object at 0x7f237f63dd30>, 'color': array([1, 1, 1, 1])}
# DEBUG:gym-duckietown:Invalid pose. Collision free: True On drivable area: False
# DEBUG:gym-duckietown:safety_factor: 1.3
# DEBUG:gym-duckietown:pos: [3.72374276 0.         2.92254342]
# DEBUG:gym-duckietown:l_pos: [3.64056496 0.         2.97341289]
# DEBUG:gym-duckietown:r_pos: [3.80692057 0.         2.87167395]
# DEBUG:gym-duckietown:f_pos: [3.6626994  0.         2.82273006]
# INFO:gym-duckietown:Starting at [3.72341583 0.         2.54024623] 3.9311260921833178
# Initialized environment
# Initialized Wrappers
# state_dim: (3, 120, 160)
# action_dim: 2
# max_action: 1.0

# %%
import argparse

parser = argparse.ArgumentParser()

# DDPG Args
parser.add_argument("--seed", default=0, type=int)  # Sets Gym, PyTorch and Numpy seeds
parser.add_argument(
    "--start_timesteps", default=1e4, type=int
)  # How many time steps purely random policy is run for
parser.add_argument("--eval_freq", default=5e3, type=float)  # How often (time steps) we evaluate
parser.add_argument("--max_timesteps", default=1e6, type=float)  # Max time steps to run environment for
parser.add_argument("--save_models", action="store_true", default=True)  # Whether or not models are saved
parser.add_argument("--expl_noise", default=0.1, type=float)  # Std of Gaussian exploration noise
parser.add_argument("--batch_size", default=32, type=int)  # Batch size for both actor and critic
parser.add_argument("--discount", default=0.99, type=float)  # Discount factor
parser.add_argument("--tau", default=0.005, type=float)  # Target network update rate
parser.add_argument(
    "--policy_noise", default=0.2, type=float
)  # Noise added to target policy during critic update
parser.add_argument("--noise_clip", default=0.5, type=float)  # Range to clip target policy noise
parser.add_argument("--policy_freq", default=2, type=int)  # Frequency of delayed policy updates
parser.add_argument("--env_timesteps", default=500, type=int)  # Frequency of delayed policy updates
parser.add_argument(
    "--replay_buffer_max_size", default=10000, type=int
)  # Maximum number of steps to keep in the replay buffer
parser.add_argument("--model-dir", type=str, default="reinforcement/pytorch/models/")
# Out:
# _StoreAction(option_strings=['--model-dir'], dest='model_dir', nargs=None, const=None, default='reinforcement/pytorch/models/', type=<class 'str'>, choices=None, help=None, metavar=None)

# %%
from env.learning.train_reinforcement import _train

_train(parser.parse_args())
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /root/mnt/final-task/execution.ipynb Cell 6' in <cell line: 3>()
#       <a href='vscode-notebook-cell://attached-container%2B7b22636f6e7461696e65724e616d65223a222f63617463687570222c2273657474696e6773223a7b22686f7374223a227373683a2f2f732d74616b6174614031302e372e312e3732227d7d/root/mnt/final-task/execution.ipynb#ch0000010vscode-remote?line=0'>1</a> from env.learning.train_reinforcement import _train
# ----> <a href='vscode-notebook-cell://attached-container%2B7b22636f6e7461696e65724e616d65223a222f63617463687570222c2273657474696e6773223a7b22686f7374223a227373683a2f2f732d74616b6174614031302e372e312e3732227d7d/root/mnt/final-task/execution.ipynb#ch0000010vscode-remote?line=2'>3</a> _train(parser.parse_args)
#
# File ~/mnt/final-task/env/learning/train_reinforcement.py:21, in _train(args)
#      <a href='file:///root/mnt/final-task/env/learning/train_reinforcement.py?line=18'>19</a> if not os.path.exists("./results"):
#      <a href='file:///root/mnt/final-task/env/learning/train_reinforcement.py?line=19'>20</a>     os.makedirs("./results")
# ---> <a href='file:///root/mnt/final-task/env/learning/train_reinforcement.py?line=20'>21</a> if not os.path.exists(args.model_dir):
#      <a href='file:///root/mnt/final-task/env/learning/train_reinforcement.py?line=21'>22</a>     os.makedirs(args.model_dir)
#      <a href='file:///root/mnt/final-task/env/learning/train_reinforcement.py?line=23'>24</a> # Launch the env with our helper function
#
# AttributeError: 'function' object has no attribute 'model_dir'
